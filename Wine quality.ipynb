# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Nidhi\Desktop\WineQT.csv")

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1138                 29.0                  40.0  0.99574  3.42       0.75
# 1139                 28.0                  38.0  0.99651  3.42       0.82
# 1140                 32.0                  44.0  0.99490  3.45       0.58
# 1141                 39.0                  51.0  0.99512  3.52       0.76
# 1142                 32.0                  44.0  0.99547  3.57       0.71
#
#       alcohol  quality    Id
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.count()
# Out:
# fixed acidity           1143
# volatile acidity        1143
# citric acid             1143
# residual sugar          1143
# chlorides               1143
# free sulfur dioxide     1143
# total sulfur dioxide    1143
# density                 1143
# pH                      1143
# sulphates               1143
# alcohol                 1143
# quality                 1143
# Id                      1143
# dtype: int64

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.shape
# Out:
# (1143, 13)

# %%
df['pH'].value_counts()
# Out:
# pH
# 3.30    41
# 3.36    40
# 3.38    38
# 3.39    37
# 3.26    33
#         ..
# 2.86     1
# 3.74     1
# 3.71     1
# 3.70     1
# 2.90     1
# Name: count, Length: 87, dtype: int64

# %%
(df['pH'].value_counts()).sort_values()
# Out:
# pH
# 2.74     1
# 2.95     1
# 2.86     1
# 3.74     1
# 3.71     1
#         ..
# 3.26    33
# 3.39    37
# 3.38    38
# 3.36    40
# 3.30    41
# Name: count, Length: 87, dtype: int64

# %%
df.rename(columns={'pH':'PH'})
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df1=df.groupby('pH')
df1

# %%
df1.size()
# Out:
# pH
# 2.74    1
# 2.86    1
# 2.88    2
# 2.89    3
# 2.90    1
#        ..
# 3.74    1
# 3.75    1
# 3.78    2
# 3.90    2
# 4.01    2
# Length: 87, dtype: int64

# %%
df1.first()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# pH
# 2.74            9.2              0.52         1.00             3.4      0.610
# 2.86           14.3              0.31         0.74             1.8      0.075
# 2.88           12.6              0.31         0.72             2.2      0.072
# 2.89           10.7              0.43         0.39             2.2      0.106
# 2.90            9.1              0.76         0.68             1.7      0.414
# ...             ...               ...          ...             ...        ...
# 3.74            5.0              1.04         0.24             1.6      0.050
# 3.75            5.0              1.02         0.04             1.4      0.045
# 3.78            5.4              0.42         0.27             2.0      0.092
# 3.90            4.6              0.52         0.15             2.1      0.054
# 4.01            5.4              0.74         0.00             1.2      0.041
#
# ...

# %%
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %%
df.isnull()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             False             False        False           False      False
# 1             False             False        False           False      False
# 2             False             False        False           False      False
# 3             False             False        False           False      False
# 4             False             False        False           False      False
# ...             ...               ...          ...             ...        ...
# 1138          False             False        False           False      False
# 1139          False             False        False           False      False
# 1140          False             False        False           False      False
# 1141          False             False        False           False      False
# 1142          False             False        False           False      False
#
# ...

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.drop_duplicates(subset=['pH'])
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00             1.9      0.076
# 1              7.8              0.88         0.00             2.6      0.098
# 2              7.8              0.76         0.04             2.3      0.092
# 3             11.2              0.28         0.56             1.9      0.075
# 6              7.9              0.60         0.06             1.6      0.069
# ..             ...               ...          ...             ...        ...
# 760            7.9              0.30         0.68             8.3      0.050
# 785            5.4              0.42         0.27             2.0      0.092
# 898            5.0              0.38         0.01             1.6      0.048
# 933            5.4              0.74         0.00             1.2      0.041
# 934            9.1              0.76         0.68             1.7      0.414
#
# ...

# %%
df.drop_duplicates(subset=['pH']).shape
# Out:
# (87, 13)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
plt.bar(df.index[:10], df['quality'][:10])
plt.xlabel("Wine Index")
plt.ylabel("Quality")
plt.title("Bar Chart of First 10 Wine Qualities")
plt.show()

# %%
plt.hist(df['quality'])
plt.xlabel("Quality")
plt.ylabel("Frequency")
plt.title("Histogram of Wine Quality")
plt.show()

# %%
quality_bins = pd.cut(df['quality'], bins=3)
quality_count = quality_bins.value_counts()

plt.pie(quality_count, labels=quality_count.index, autopct='%1.1f%%')
plt.title("Pie Chart of Wine Quality Distribution")
plt.show()

# %%
plt.plot(df.index, df['quality'])
plt.xlabel("Wine Index")
plt.ylabel("Quality")
plt.title("Line Chart of Wine Quality")
plt.show()

# %%
plt.scatter(df['alcohol'], df['quality'])
plt.xlabel("Alcohol")
plt.ylabel("Quality")
plt.title("Scatter Plot: Alcohol vs Quality")
plt.show()

# %%
plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.hist(df['quality'])
plt.title("Histogram of Quality")

plt.subplot(2, 2, 2)
plt.scatter(df['alcohol'], df['quality'])
plt.title("Alcohol vs Quality")

plt.subplot(2, 2, 3)
plt.plot(df.index, df['quality'])
plt.title("Line Chart of Quality")

plt.subplot(2, 2, 4)
plt.bar(df.index[:10], df['quality'][:10])
plt.title("Bar Chart of Quality")

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.relplot(x='alcohol', y='quality', data=df)

# %%
sns.scatterplot(x='alcohol', y='quality', data=df)
plt.title("Scatter Plot: Alcohol vs Quality")
plt.show()

# %%
sns.lineplot(x=df.index, y='quality', data=df)
plt.title("Line Plot of Wine Quality")
plt.show()

# %%
sns.distplot(df['quality'])
plt.title("Distplot of Wine Quality")
plt.show()
# Out:
# C:\Users\Nidhi\AppData\Local\Temp\ipykernel_12676\547471235.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['quality'])

# %%
sns.histplot(df['quality'])
plt.title("Histplot of Wine Quality")
plt.show()

# %%
sns.kdeplot(df['quality'])
plt.title("KDE Plot of Wine Quality")
plt.show()

# %%
sns.boxplot(y='quality', data=df)
plt.title("Boxplot of Wine Quality")
plt.show()

# %%
sns.violinplot(y='quality', data=df)
plt.title("Violin Plot of Wine Quality")
plt.show()

# %%
sns.barplot(x=df.index[:10], y=df['quality'][:10])
plt.title("Barplot of First 10 Wines")
plt.show()

# %%
quality_category = pd.cut(df['quality'], bins=3)
sns.countplot(x=quality_category)
plt.title("Countplot of Wine Quality Categories")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
sns.heatmap(numeric_df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
numeric_df = df.select_dtypes(include=['int64', 'float64'])
sns.pairplot(numeric_df[['alcohol','volatile acidity','citric acid','quality']])
