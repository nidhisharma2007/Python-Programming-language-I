# %%
#EDA operations and Seaborn Libraries
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"SampleSuperstore.csv")

# %%
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %%
df.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# 9991       0.2  19.3932
# 9992       0.0  13.3200
# 9993       0.0  72.9480

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.count()
# Out:
# Ship Mode       9994
# Segment         9994
# Country         9994
# City            9994
# State           9994
# Postal Code     9994
# Region          9994
# Category        9994
# Sub-Category    9994
# Sales           9994
# Quantity        9994
# Discount        9994
# Profit          9994
# dtype: int64

# %%
df.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
df.shape
# Out:
# (9994, 13)

# %%
df['Region'].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
(df['Region'].value_counts()).sort_values(ascending=False)
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df.sort_values('Region')
# Out:
#            Ship Mode      Segment        Country         City       State  \
# 2594  Standard Class    Corporate  United States     Columbus     Indiana
# 8943  Standard Class     Consumer  United States       Aurora    Illinois
# 6665    Second Class     Consumer  United States       Irving       Texas
# 2923  Standard Class    Corporate  United States      Detroit    Michigan
# 2922    Second Class  Home Office  United States       Austin       Texas
# ...              ...          ...            ...          ...         ...
# 3225     First Class    Corporate  United States        Tempe     Arizona
# 3224     First Class    Corporate  United States        Tempe     Arizona
# 7793    Second Class    Corporate  United States    Las Vegas      Nevada
# 3247    Second Class    Corporate  United States      Seattle  Washington
# 9993    Second Class     Consumer  United States  Westminster  California
#
#       Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 2594        47201  Central  Office Supplies    Envelopes  180.960         2
# 8943        60505  Central        Furniture       Chairs  239.358         3
# 6665        75061  Central  Office Supplies        Paper  219.840         5
# 2923        48234  Central  Office Supplies    Fasteners    6.080         1
# 2922        78745  Central  Office Supplies      Binders    3.882         3
# ...           ...      ...              ...          ...      ...       ...
# 3225        85281     West  Office Supplies    Envelopes   12.768         6
# 3224        85281     West       Technology       Phones  318.400         2
# 7793        89115     West  Office Supplies        Paper   32.400         5
# 3247        98103     West  Office Supplies          Art   18.240         3
# 9993        92683     West  Office Supplies   Appliances  243.160         2
#
#       Discount    Profit
# 2594       0.0   81.4320
# 8943       0.3  -47.8716
# 6665       0.2   79.6920
# 2923       0.0    3.0400
# 2922       0.8   -5.8230
# ...        ...       ...
# 3225       0.2    4.6284
# 3224       0.2  107.4600
# 7793       0.0   15.8760
# 3247       0.0    5.2896
# 9993       0.0   72.9480
#
# [9994 rows x 13 columns]

# %%
df.rename(columns={'Segment':'Segments'})
# Out:
#            Ship Mode   Segments        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
#       Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0           42420  South        Furniture    Bookcases  261.9600         2
# 1           42420  South        Furniture       Chairs  731.9400         3
# 2           90036   West  Office Supplies       Labels   14.6200         2
# 3           33311  South        Furniture       Tables  957.5775         5
# 4           33311  South  Office Supplies      Storage   22.3680         2
# ...           ...    ...              ...          ...       ...       ...
# 9989        33180  South        Furniture  Furnishings   25.2480         3
# 9990        92627   West        Furniture  Furnishings   91.9600         2
# 9991        92627   West       Technology       Phones  258.5760         2
# 9992        92627   West  Office Supplies        Paper   29.6000         4
# 9993        92683   West  Office Supplies   Appliances  243.1600         2
#
#       Discount    Profit
# 0         0.00   41.9136
# 1         0.00  219.5820
# 2         0.00    6.8714
# 3         0.45 -383.0310
# 4         0.20    2.5164
# ...        ...       ...
# 9989      0.20    4.1028
# 9990      0.00   15.6332
# 9991      0.20   19.3932
# 9992      0.00   13.3200
# 9993      0.00   72.9480
#
# [9994 rows x 13 columns]

# %%
df1=df.groupby('Region')
df1

# %%
df1.size()
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# dtype: int64

# %%
df1.first()
# Out:
#               Ship Mode      Segment        Country          City  \
# Region
# Central  Standard Class  Home Office  United States    Fort Worth
# East       Second Class     Consumer  United States  Philadelphia
# South      Second Class     Consumer  United States     Henderson
# West       Second Class    Corporate  United States   Los Angeles
#
#                 State  Postal Code         Category Sub-Category    Sales  \
# Region
# Central         Texas        76106  Office Supplies   Appliances   68.810
# East     Pennsylvania        19140        Furniture       Chairs   71.372
# South        Kentucky        42420        Furniture    Bookcases  261.960
# West       California        90036  Office Supplies       Labels   14.620
#
#          Quantity  Discount    Profit
# Region
# Central         5       0.8 -123.8580
# East            2       0.3   -1.0196
# South           2       0.0   41.9136
# West            2       0.0    6.8714

# %%
df.isnull()
# Out:
#       Ship Mode  Segment  Country   City  State  Postal Code  Region  \
# 0         False    False    False  False  False        False   False
# 1         False    False    False  False  False        False   False
# 2         False    False    False  False  False        False   False
# 3         False    False    False  False  False        False   False
# 4         False    False    False  False  False        False   False
# ...         ...      ...      ...    ...    ...          ...     ...
# 9989      False    False    False  False  False        False   False
# 9990      False    False    False  False  False        False   False
# 9991      False    False    False  False  False        False   False
# 9992      False    False    False  False  False        False   False
# 9993      False    False    False  False  False        False   False
#
#       Category  Sub-Category  Sales  Quantity  Discount  Profit
# 0        False         False  False     False     False   False
# 1        False         False  False     False     False   False
# 2        False         False  False     False     False   False
# 3        False         False  False     False     False   False
# 4        False         False  False     False     False   False
# ...        ...           ...    ...       ...       ...     ...
# 9989     False         False  False     False     False   False
# 9990     False         False  False     False     False   False
# 9991     False         False  False     False     False   False
# 9992     False         False  False     False     False   False
# 9993     False         False  False     False     False   False
#
# [9994 rows x 13 columns]

# %%
df.drop_duplicates(subset=['Region'])
# Out:
#          Ship Mode      Segment        Country          City         State  \
# 0     Second Class     Consumer  United States     Henderson      Kentucky
# 2     Second Class    Corporate  United States   Los Angeles    California
# 14  Standard Class  Home Office  United States    Fort Worth         Texas
# 23    Second Class     Consumer  United States  Philadelphia  Pennsylvania
#
#     Postal Code   Region         Category Sub-Category    Sales  Quantity  \
# 0         42420    South        Furniture    Bookcases  261.960         2
# 2         90036     West  Office Supplies       Labels   14.620         2
# 14        76106  Central  Office Supplies   Appliances   68.810         5
# 23        19140     East        Furniture       Chairs   71.372         2
#
#     Discount    Profit
# 0        0.0   41.9136
# 2        0.0    6.8714
# 14       0.8 -123.8580
# 23       0.3   -1.0196

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Relplot – Sales vs Profit
sns.relplot(x='Sales', y='Profit', data=df)
plt.title("Relational Plot: Sales vs Profit")
plt.show()

# %%
#Scatterplot – Sales vs Profit
sns.scatterplot(x='Sales', y='Profit', data=df)
plt.title("Scatter Plot: Sales vs Profit")
plt.show()

# %%
#Distplot – Sales Distribution
sns.distplot(df['Sales'], kde=True)
plt.title("Distplot: Sales Distribution")
plt.show()
# Out:
# C:\Users\Nidhi\AppData\Local\Temp\ipykernel_16108\3235515881.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sales'], kde=True)

# %%
#Histplot – Sales Distribution
sns.histplot(df['Sales'], bins=30, kde=True)
plt.title("Histogram: Sales Distribution")
plt.show()

# %%
#KDE Plot – Profit Distribution
sns.kdeplot(df['Profit'], fill=True)
plt.title("KDE Plot: Profit Distribution")
plt.show()

# %%
#Boxplot – Sales (Outlier Detection)
sns.boxplot(y='Sales', data=df)
plt.title("Boxplot: Sales")
plt.show()

# %%
#Violin Plot – Profit by Category
sns.violinplot(x='Category', y='Profit', data=df)
plt.title("Violin Plot: Profit by Category")
plt.show()

# %%
#Barplot – Average Sales by Category
sns.barplot(x='Category', y='Sales', data=df)
plt.title("Bar Plot: Average Sales by Category")
plt.show()

# %%
#Lineplot-Sales trend in Superstore
df = df.reset_index()

sns.lineplot(x="index", y="Sales", data=df)

plt.xlabel("Index")
plt.ylabel("Sales")
plt.title("Sales Trend in Superstore Dataset")
plt.show()

# %%
#Countplot – Orders by Segment
sns.countplot(x='Segment', data=df)
plt.title("Count Plot: Orders by Segment")
plt.show()

# %%
#Heatmap 
plt.figure(figsize=(8,6))
sns.heatmap(df[['Sales','Profit','Quantity','Discount']].corr(),
            annot=True, cmap='coolwarm')
plt.title("Heatmap: Correlation Matrix")
plt.show()

# %%
#Pairplot
sns.pairplot(df[['Sales','Profit','Quantity','Discount']])
plt.show()
