# %%
student=['Nidhi','Prastuti','Mayank','Himanshu','Mehar','Haadiya','Nihal','Manav','Harshita','Ansh']
print(type(student))
# Out:
# <class 'list'>

# %%
student=['Nidhi','Prastuti','Mayank','Himanshu','Mehar','Haadiya','Nihal','Manav','Harshita','Ansh']
print(student[ :3])
# Out:
# ['Nidhi', 'Prastuti', 'Mayank']

# %%
print(student[3:5])
# Out:
# ['Himanshu', 'Mehar']

# %%
print(student[-4:-2])
# Out:
# ['Nihal', 'Manav']

# %%
student=['Nidhi','Prastuti','Mayank','Himanshu','Mehar','Haadiya','Nihal','Manav','Harshita','Ansh']
student.append('Anup')
print(student)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Haadiya', 'Nihal', 'Manav', 'Harshita', 'Ansh', 'Anup']

# %%
student.insert(5,'Himanshi')
print(student)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Himanshi', 'Haadiya', 'Nihal', 'Manav', 'Harshita', 'Ansh', 'Anup']

# %%
student=['Nidhi','Prastuti','Mayank','Himanshu','Mehar','Haadiya','Nihal','Manav','Harshita','Ansh']
student.extend(company)
print(student)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Haadiya', 'Nihal', 'Manav', 'Harshita', 'Ansh', 'TCS', 'Wipro', 'Infosys', 'Algo', 'Statistics']

# %%
student=['Nidhi','Prastuti','Mayank','Himanshu','Mehar','Haadiya','Nihal','Manav','Harshita','Ansh']
student.remove('Harshita')
print(student)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Haadiya', 'Nihal', 'Manav', 'Ansh']

# %%
student.pop()
print(student)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Haadiya', 'Nihal', 'Manav']

# %%
student.pop(5)
# Out:
# 'Haadiya'

# %%
print(student)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Nihal', 'Manav']

# %%
del student[6]
print(student)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Nihal']

# %%
student=['Nidhi','Prastuti','Mayank','Himanshu','Mehar','Haadiya','Nihal','Manav','Harshita','Ansh']
stud1=student.copy()
print(stud1)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Haadiya', 'Nihal', 'Manav', 'Harshita', 'Ansh']

# %%
stud2=list(student)
print(stud2)
# Out:
# ['Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Haadiya', 'Nihal', 'Manav', 'Harshita', 'Ansh']

# %%
stud1=['A','B','C','D','E']
student=['Nidhi','Prastuti','Mayank','Himanshu','Mehar','Haadiya','Nihal','Manav','Harshita','Ansh']
stud3=stud1+student
print(stud3)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'Nidhi', 'Prastuti', 'Mayank', 'Himanshu', 'Mehar', 'Haadiya', 'Nihal', 'Manav', 'Harshita', 'Ansh']

# %%
print(max(stud1))
# Out:
# E

# %%
print(min(stud1))
# Out:
# A

# %%
stud2=['a','b','c','d','e']
stud2.clear()
print(stud2)
# Out:
# []

# %%
del stud1
print(stud1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 del stud1
# ----> 2 print(stud1)
#
# NameError: name 'stud1' is not defined
